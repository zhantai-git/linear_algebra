# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ### Algebraic and geometric interpretations

# %%
# 2-dimensional vector
v2 = [3, -2]

# 3-dimensional vector
v3 = [4, -3, 2]

# row to column (or vice-verca):
v3t = np.transpose(v3)


# plot them
v2 = [1, 2]
plt.plot([0,v2[0]],[0,v2[1]])

plt.axis('equal')
plt.plot([-4, 4],[0, 0], 'k--')
plt.plot([0, 0],[-4, 4], 'k--')
plt.grid()
plt.axis((-4, 4, -4, 4))
plt.show()
# Out:
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
# plot in 3d
fig = plt.figure(figsize=plt.figaspect(1))
ax = fig.add_subplot(111, projection='3d')
ax.plot([0, v3[0]],[0, v3[1]],[0, v3[2]], linewidth=3)

# make the plot look nicer
ax.plot([0, 0],[0, 0],[-4, 4], 'k--')
ax.plot([0, 0],[-4, 4], [0, 0], 'k--')
ax.plot([-4, 4],[0, 0], [0, 0], 'k--')
plt.show()

# %% [markdown]
# ### Vector addition and substraction

# %%
# two vectors in R2
v1 = np.array([3, -1])
v2 = np.array([2, 4])

v3 = v1 + v2

# plot them
plt.plot([0,v1[0]], [0,v1[1]],'b',label='v1')
plt.plot([0,v2[0]]+v1[0], [0,v2[1]]+v1[1],'r',label='v2')
plt.plot([0,v3[0]], [0,v3[1]],'k',label='v1+v2')

plt.legend()
plt.axis('square')
plt.axis((-6, 6, -6, 6))
plt.grid()
plt.show()

# %%
v3
# Out:
# array([5, 3])

# %%
v_1 = np.array([1, 1, 2])
v_2 = np.array([1, 2, 4])
v_3 = v_1 + v_2


# plot in 3d
fig = plt.figure(figsize=plt.figaspect(1))
ax = fig.add_subplot(111, projection='3d')
ax.plot([0, v_3[0]],[0, v_3[1]],[0, v_3[2]], linewidth=3)
ax.plot([0, v_1[0]],[0, v_1[1]],[0, v_1[2]], linewidth=3)
ax.plot([v_1[0], v_2[0]+v_1[0]],[v_1[1], v_2[1]+v_1[1]],[v_1[2], v_2[2]+v_1[2]], linewidth=3)
# make the plot look nicer
ax.plot([0, 0],[0, 0],[-6, 6], 'k--')
ax.plot([0, 0],[-6, 6], [0, 0], 'k--')
ax.plot([-6, 6],[0, 0], [0, 0], 'k--')
plt.show()

# %%
import plotly.graph_objects as go

# 3d with plotly
v_1 = np.array([2, 1, 2])
v_2 = np.array([1, 2, 4])
v_3 = v_1 + v_2
# Создаём линии как traces
fig = go.Figure()

# Вектор v_1
fig.add_trace(go.Scatter3d(
    x=[0, v_1[0]],
    y=[0, v_1[1]],
    z=[0, v_1[2]],
    mode='lines',
    line=dict(color='red', width=5),
    name='v_1'
))

# Вектор v_2 от конца v_1
fig.add_trace(go.Scatter3d(
    x=[v_1[0], v_2[0]+v_1[0]],
    y=[v_1[1], v_2[1]+v_1[1]],
    z=[v_1[2], v_2[2]+v_1[2]],
    mode='lines',
    line=dict(color='green', width=5),
    name='v_2'
))
# Вектор v_3
fig.add_trace(go.Scatter3d(
    x=[0, v_3[0]],
    y=[0, v_3[1]],
    z=[0, v_3[2]],
    mode='lines',
    line=dict(color='blue', width=5),
    name='v_3'
))

# Оси координат
fig.add_trace(go.Scatter3d(
    x=[-6, 6], y=[0, 0], z=[0, 0],
    mode='lines',
    line=dict(color='black', width=2, dash='dash'),
    showlegend=False
))

fig.add_trace(go.Scatter3d(
    x=[0, 0], y=[-6, 6], z=[0, 0],
    mode='lines',
    line=dict(color='black', width=2, dash='dash'),
    showlegend=False
))

fig.add_trace(go.Scatter3d(
    x=[0, 0], y=[0, 0], z=[-6, 6],
    mode='lines',
    line=dict(color='black', width=2, dash='dash'),
    showlegend=False
))

# Настройка внешнего вида
fig.update_layout(
    scene=dict(
        xaxis=dict(range=[-6, 6]),
        yaxis=dict(range=[-6, 6]),
        zaxis=dict(range=[-6, 6]),
        aspectmode='cube'
    ),
    width=800,
    height=800
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a86772ea-b292-4c2b-99e1-480a02d69582" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a86772ea-b292-4c2b-99e1-480a02d69582")) {                    Plotly.newPlot(                        "a86772ea-b292-4c2b-99e1-480a02d69582",                        [{"line":{"color":"red","width":5},"mode":"lines","name":"v_1","x":[0,2],"y":[0,1],"z":[0,2],"type":"scatter3d"},{"line":{"color":"green","width":5},"mode":"lines","name":"v_2","x":[2,3],"y":[1,3],"z":[2,6],"type":"scatter3d"},{"line":{"color":"blue","width":5},"mode":"lines","name":"v_3","x":[0,3],"y":[0,3],"z":[0,6],"type":"scatter3d"},{"line":{"color":"black","dash":"dash","width":2},"mode":"lines","showlegend":false,"x":[-6,6],"y":[0,0],"z":[0,0],"type":"scatter3d"},{"line":{"color":"black","dash":"dash","width":2},"mode":"lines","showlegend":false,"x":[0,0],"y":[-6,6],"z":[0,0],"type":"scatter3d"},{"line":{"color":"black","dash":"dash","width":2},"mode":"lines","showlegend":false,"x":[0,0],"y":[0,0],"z":[-6,6],"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}] ...
